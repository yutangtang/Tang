# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re

driver = webdriver.Firefox()
driver.implicitly_wait(30)
base_url = "http://jirs.judicial.gov.tw"   

driver.get(base_url + "/FJUD/FJUDQRY01_1.aspx")
Select(driver.find_element_by_name("v_court")).select_by_visible_text(u"最高法院")
driver.find_elements_by_css_selector("input[type='radio'][value='V']")[0].click()
driver.find_element_by_id("jt").clear()
driver.find_element_by_id("jt").send_keys(u"保險")
driver.find_element_by_name("Button").click()
soup = BeautifulSoup(driver.page_source)
table = soup.select('#Table3')[0]
hrefs = table.select('a')
for href in hrefs[0:1]:
    print href['href'][0:]
# Out:
# FJUDQRY03_1.aspx?id=1&v_court=TPS+%e6%9c%80%e9%ab%98%e6%b3%95%e9%99%a2&v_sys=V&jud_year=&jud_case=&jud_no=&jud_no_end=&jud_title=%e4%bf%9d%e9%9a%aa&keyword=&sdate=&edate=&page=&searchkw=&jmain=&cw=0

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re

driver = webdriver.Firefox()
driver.implicitly_wait(30)
base_url = "http://jirs.judicial.gov.tw"   

driver.get(base_url + "/FJUD/FJUDQRY01_1.aspx")
Select(driver.find_element_by_name("v_court")).select_by_visible_text(u"最高法院")
driver.find_elements_by_css_selector("input[type='radio'][value='V']")[0].click()
driver.find_element_by_id("jt").clear()
driver.find_element_by_id("jt").send_keys(u"保險")
driver.find_element_by_name("Button").click()
for i in range(0,2):
    url
    driver.find_element_by_link_text(u"105,台上,114").click()
    soup = BeautifulSoup(driver.page_source)
    print soup.text

driver.find_element_by_link_text(u"105,台上,43").click()
soup = BeautifulSoup(driver.page_source)
print soup.text
# Out:
# 最高法院-民-105台上114
#
#
#
#
#
#
#
# 			&lt;!--
# 			pre{font-family:細明體}
# 			--&gt;
#
#
# function openwin(URL,arguments,width,height)
# {
#    //功能:開一個非獨佔的視窗
#    //參數1.URL :連結的網頁
#    //參數2.arguments :傳入網頁的參數
#    /*
#    var str = URL  //+"?"+arguments;
#    newWindow=top.open("","","maximize=no,toolbar=no,directories=no,status=yes,scrollbars=yes,hscrollbars=no,resize=no,menubar=no");
#    if(width==null&amp;&amp;height==null)
#    {
#      width=screen.width;
#      height=screen.availHeight;
#
#    }
#    if ((width!=null)&amp;&amp;(height!=null))
#       newWindow.resizeTo(width,height);
#    else
#       newWindow.resizeTo(screen.width,screen.availHeight);
#    newWindow.moveTo((screen.width-width)/2,(screen.availHeight-height)/2);
#    newWindow.location=str;
#    */
#
#    if((width==null&amp;&amp;height==null) || (width==''&amp;&amp;height==''))
#    {
# 		width=screen.width;
# 		height=screen.availHeight;
#    }
# ...

# %% [markdown]
# ## 目前最新進度

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re, os
import random

driver = webdriver.Firefox()
driver.implicitly_wait(30)
base_url = "http://jirs.judicial.gov.tw"   
driver.get(base_url + "/FJUD/FJUDQRY01_1.aspx")
Select(driver.find_element_by_name("v_court")).select_by_visible_text(u"最高法院")
driver.find_elements_by_css_selector("input[type='radio'][value='V']")[0].click()
driver.find_element_by_id("jt").clear()
driver.find_element_by_id("jt").send_keys(u"保險")
driver.find_element_by_name("Button").click()
#soup = BeautifulSoup(driver.page_source)
#hrefs = soup.select('a')
#for href in hrefs[2:1:-4]:
    #print href.text
driver.find_element_by_link_text("105,台上,114").click()
soup = BeautifulSoup(driver.page_source)
#print soup.text

for i in range(0,189):
    #print time.ctime()
    #time.sleep(random.randint(5,8))
    driver.find_element_by_link_text(u"下一筆").click()
    soup = BeautifulSoup(driver.page_source)
    print time.ctime()
    #print soup.text
    time.sleep(random.randint(1,1000)/1000)
# Out:
# Thu Mar 10 20:28:30 2016
# Thu Mar 10 20:28:31 2016
# Thu Mar 10 20:28:55 2016
# Thu Mar 10 20:28:56 2016
# Thu Mar 10 20:28:56 2016
# Thu Mar 10 20:28:57 2016
# Thu Mar 10 20:28:58 2016
# Thu Mar 10 20:28:59 2016
# Thu Mar 10 20:29:35 2016
# Thu Mar 10 20:29:35 2016
# Thu Mar 10 20:29:36 2016
# Thu Mar 10 20:29:37 2016
# Thu Mar 10 20:30:03 2016
# Thu Mar 10 20:30:41 2016
# Thu Mar 10 20:30:42 2016
# Thu Mar 10 20:31:07 2016
# Thu Mar 10 20:31:07 2016
# Thu Mar 10 20:31:47 2016
# Thu Mar 10 20:31:47 2016
# Thu Mar 10 20:31:48 2016
# Thu Mar 10 20:31:48 2016
# Thu Mar 10 20:31:49 2016
# Thu Mar 10 20:31:49 2016
# Thu Mar 10 20:32:29 2016
# Thu Mar 10 20:32:30 2016
# Thu Mar 10 20:32:30 2016
# Thu Mar 10 20:32:31 2016
# Thu Mar 10 20:32:31 2016
# Thu Mar 10 20:32:53 2016
# Thu Mar 10 20:32:53 2016
# Thu Mar 10 20:32:54 2016
# Thu Mar 10 20:32:54 2016
# Thu Mar 10 20:32:55 2016
# Thu Mar 10 20:32:55 2016
# Thu Mar 10 20:32:56 2016
# Thu Mar 10 20:32:56 2016
# Thu Mar 10 20:32:57 2016
# ...

# %% [markdown]
# ## 抓取200筆

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re, os
import random

driver = webdriver.Firefox()
driver.implicitly_wait(30)
base_url = "http://jirs.judicial.gov.tw"   
driver.get(base_url + "/FJUD/FJUDQRY01_1.aspx")
Select(driver.find_element_by_name("v_court")).select_by_visible_text(u"最高法院")
driver.find_elements_by_css_selector("input[type='radio'][value='V']")[0].click()
driver.find_element_by_id("jt").clear()
driver.find_element_by_id("jt").send_keys(u"保險")
driver.find_element_by_name("Button").click()
#soup = BeautifulSoup(driver.page_source)
#hrefs = soup.select('a')
#for href in hrefs[2:1:-4]:
    #print href.text
driver.find_element_by_link_text("105,台上,114").click()
soup = BeautifulSoup(driver.page_source)
#print soup.text
f = open('/Users/BIG DATA/Desktop/project/1.text','w')
f.write(soup.prettify().encode('utf-8'))
f.close()


for i in range(0,200):
    driver.find_element_by_link_text(u"下一筆").click()
    soup = BeautifulSoup(driver.page_source)
    f = open('/Users/BIG DATA/Desktop/project/{}.text'.format(i+2),'w')
    f.write(soup.prettify().encode('utf-8'))
    f.close()
# Out:
# C:\Users\BIG DATA\Anaconda2\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-1-0fcff082cfcb> in <module>()
#      32
#      33 for i in range(0,200):
# ---> 34     driver.find_element_by_link_text(u"下一筆").click()
#      35     soup = BeautifulSoup(driver.page_source)
#      36     f = open('/Users/BIG DATA/Desktop/project/{}.text'.format(i+2),'w')
#
# ...

# %%
        
    f = open('/Users/BIG DATA/Desktop/project/2.text','w')
    f.write(to_file.prettify().encode('utf-8'))
    f.close()
